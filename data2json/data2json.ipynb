# %%
import os
import json
import pandas as pd

# %%
path = os.getcwd()
files = os.listdir(path+'\\dataSets')
files
# Out:
# ['ByAPT.csv',
#  'ByWeapon.csv',
#  'newByCompany.csv',
#  'newByCountry.csv',
#  'newByIndustry.csv',
#  'newByReportType.csv',
#  'newByYear.csv',
#  'report_info.csv']

# %%
detailList = []
attackMethod = []
detailDict = {}
res_dict = {}
# detailDict = {
#     "报告标题":reportTitle,
#     "披露时间":exploreTime,
#     "披露机构":exploreAgen,
#     "攻击手法":attackMethod,
#     "攻击国家":attackCountry,
#     "攻击工具":attackTools,
#     "报告摘要":reportBrief,
# }


# {
#     id:{
#         "组织名称":name,
#         "组织别名":nickname
#         "归属国家":country,
#         "归并":detailList
#     }
# }

# %%
filename = path + '\\dataSets\\' + files[0]
with open(filename, 'r', encoding='utf-8-sig') as fr:
    data = pd.read_csv(fr, encoding='utf-8-sig')
for index in data.index:    # 按行遍历
    row = data.loc[index].values[0:]  # narray
    for i in range(8):
        if row[0] in res_dict.keys():
            row[1] = detailDict["]
# Out:
# Ajax Security Team
# Iran
# Ajax Security Team
# 鱼叉式网络钓鱼攻击
# 暂无数据
# 暂无数据
# 暂无数据
# 暂无数据
# Anunak
# Russian Federation
# [FIN7,Anunak]
# [鱼叉式网络钓鱼攻击,恶意软件]
# 美国
# [金融,酒店,零售]
# Carbanak
# 暂无数据
# APT1
# China
# APT1
# [鱼叉式网络钓鱼,电子邮件]
# 暂无数据
# 暂无数据
# 暂无数据
# 暂无数据
# APT10
# China
# APT10
# 鱼叉式网络钓鱼攻击
# 暂无数据
# [政府,航空航天,电信运营商]
# 暂无数据
# 暂无数据
# APT12
# China
# APT12
# 网络钓鱼邮件
# 暂无数据
# 暂无数据
# 暂无数据
# 暂无数据
# APT15
# China
# Ke3Chang
# 鱼叉式网络钓鱼攻击
# 暂无数据
# 暂无数据
# 暂无数据
# 暂无数据
# APT16
# china
# APT16
# 暂无数据
# 日本
# 暂无数据
# 暂无数据
# 暂无数据
# apt17
# 中国
# [Winnti Group,Axiom,Group72]
# 暂无数据
# 暂无数据
# 暂无数据
# [Derusbi,Hikit,Hydraq,ZxShell]
# 暂无数据
# APT19
# China
# Shell Crew
# 漏洞利用
# 暂无数据
# 暂无数据
# 暂无数据
# 暂无数据
# APT23
# 暂无数据
# Tropic Trooper
# [漏洞利用,恶意软件]
# 菲律宾香港
# [政府,军事,交通运输,医疗卫生]
# 暂无数据
# 暂无数据
# APT27
# China
# [Lucky,Mouse,Emissary Panda]
# 木马后门
# 暂无数据
# 暂无数据
# 暂无数据
# 暂无数据
# APT28
# 俄罗斯
# [Sofacy,Sednit,APT-C-20,STRONTIUM,奇幻熊,Sofacy]
# [漏洞利用,社会工程学,木马后门]
# 暂无数据
# [政府,国防]
# 暂无数据
# ...
